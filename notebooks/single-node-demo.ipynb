# %%
from __future__ import print_function

# %% [markdown]
# ### TensorFlow Arhictecture

# %% [markdown]
# ![A](image6.png)

# %% [markdown]
# ### Load Libraries

# %%
import os
import sys
sys.path.append('../')

import tensorflow as tf
from models.cnn_model import CNN_Model
from data.data_pipeline import get_input_fn
from hparams.yparams import YParams
from parse_tensorboard_tfevents import get_training_history

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('demo_style.mplstyle')

# %% [markdown]
# ### Create model_fn

# %%
def model_fn(features, labels, params, mode):
    """ Build graph and return EstimatorSpec """

    is_training = (mode == tf.estimator.ModeKeys.TRAIN)

    model = CNN_Model(params, input_x=features, is_training=is_training)

    if mode is not tf.estimator.ModeKeys.PREDICT:
        # loss and optimizer are not needed for inference
        model.define_loss(labels)
        model.define_optimizer()
        model.define_train_op()

    with tf.variable_scope('eval_metrics') as _:
        eval_metrics = {}
        probs = tf.nn.sigmoid(model.logits)
        predictions = tf.round(probs)
        eval_metrics['acc'] = tf.metrics.accuracy(labels=labels, predictions=predictions)

    return tf.estimator.EstimatorSpec(loss=model.loss,
                                      train_op=model.train_op,
                                      eval_metric_ops=eval_metrics,
                                      mode=mode)

# %% [markdown]
# ### load parameters

# %%
configurations_path = '../hparams/cnn.yaml'
experiment = 'demo_single_node'
params = YParams(configurations_path, experiment)
# Out:
# train_dataset_size 128000
# valid_dataset_size 64000
# train_data_files ../data/train.h5
# valid_data_files ../data/valid.h5
# epochs 5
# experiment_dir ../logs/demo_single_node
# data_format channels_last
# input_shape ['None', 64, 64, 1]
# conv_filters [16, 32, 64]
# conv_args CommentedMap([('kernel_size', 3), ('strides', 1), ('padding', 'same'), ('activation', 'relu')])
# maxpool_args CommentedMap([('pool_size', 2), ('strides', 2)])
# conv_dropout_rate 0.2
# fc_hidden_units [256]
# fc_dropout_rates [0.2]
# fc_activation relu
# learning_rate 0.001
# batchsize 128

# %% [markdown]
# ### Create data pipelines

# %%
# create training data input pipeline
train_input_fn, train_init_hook = get_input_fn(params.train_data_files,
                                               dataset_size=params.train_dataset_size,
                                               batchsize=params.batchsize,
                                               epochs=params.epochs,
                                               variable_scope='train_data_pipeline')

max_steps = (params.train_dataset_size//params.batchsize)*params.epochs
train_spec = tf.estimator.TrainSpec(input_fn=train_input_fn,
                                    hooks=[train_init_hook],
                                    max_steps=max_steps)

# create validation data input pipeline
valid_input_fn, valid_init_hook = get_input_fn(params.valid_data_files,
                                               dataset_size=params.valid_dataset_size,
                                               batchsize=params.batchsize,
                                               epochs=params.epochs,
                                               variable_scope='valid_data_pipeline')

eval_spec = tf.estimator.EvalSpec(input_fn=valid_input_fn,
                                  hooks=[valid_init_hook],
                                  start_delay_secs=10,
                                  throttle_secs=10) # too frequent, just for demo

# %% [markdown]
# ### Build estimator

# %%
config = tf.estimator.RunConfig(save_checkpoints_secs=10) # too frequent, just for demo

# %%
estimator = tf.estimator.Estimator(model_fn=model_fn,
                                   model_dir=params.experiment_dir,
                                   config=config,
                                   params=params)
# Out:
# INFO:tensorflow:Using config: {'_master': '', '_evaluation_master': '', '_save_checkpoints_secs': 10, '_keep_checkpoint_max': 5, '_save_checkpoints_steps': None, '_service': None, '_global_id_in_cluster': 0, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_num_worker_replicas': 1, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '../logs/demo_single_node', '_train_distribute': None, '_task_id': 0, '_tf_random_seed': None, '_task_type': 'worker', '_device_fn': None, '_num_ps_replicas': 0, '_session_config': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f87cb5cb438>}

# %% [markdown]
# ### Train Model

# %%
tf.logging.set_verbosity(tf.logging.INFO)
tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 10.
# INFO:tensorflow:Calling model_fn.
# Number of model parameters 1072385
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ../logs/demo_single_node/model.ckpt.
# INFO:tensorflow:loss = 0.692472, step = 0
# INFO:tensorflow:global_step/sec: 82.6006
# INFO:tensorflow:loss = 0.364072, step = 100 (1.213 sec)
# INFO:tensorflow:global_step/sec: 91.1481
# INFO:tensorflow:loss = 0.2051, step = 200 (1.096 sec)
# INFO:tensorflow:global_step/sec: 89.4029
# INFO:tensorflow:loss = 0.209697, step = 300 (1.120 sec)
# INFO:tensorflow:global_step/sec: 88.7453
# INFO:tensorflow:loss = 0.206404, step = 400 (1.126 sec)
# INFO:tensorflow:global_step/sec: 89.9476
# INFO:tensorflow:loss = 0.258396, step = 500 (1.112 sec)
# INFO:tensorflow:global_step/sec: 90.4215
# INFO:tensorflow:loss = 0.296456, step = 600 (1.106 sec)
# INFO:tensorflow:Saving checkpoints for 629 into ../logs/demo_single_node/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# Number of model parameters 1072385
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-06-21:25:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../logs/demo_single_node/model.ckpt-629
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-06-21:25:14
# INFO:tensorflow:Saving dict for global step 629: acc = 0.909141, global_step = 629, loss = 0.226359
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 629: ../logs/demo_single_node/model.ckpt-629
# INFO:tensorflow:global_step/sec: 26.7359
# INFO:tensorflow:loss = 0.208974, step = 700 (3.740 sec)
# INFO:tensorflow:global_step/sec: 96.1003
# INFO:tensorflow:loss = 0.126251, step = 800 (1.041 sec)
# INFO:tensorflow:global_step/sec: 84.9705
# INFO:tensorflow:loss = 0.244363, step = 900 (1.177 sec)
# INFO:tensorflow:global_step/sec: 88.9952
# INFO:tensorflow:loss = 0.206224, step = 1000 (1.123 sec)
# INFO:tensorflow:global_step/sec: 99.8644
# INFO:tensorflow:loss = 0.22063, step = 1100 (1.001 sec)
# INFO:tensorflow:global_step/sec: 89.7067
# INFO:tensorflow:loss = 0.260452, step = 1200 (1.114 sec)
# INFO:tensorflow:global_step/sec: 96.3264
# INFO:tensorflow:loss = 0.265265, step = 1300 (1.039 sec)
# INFO:tensorflow:Saving checkpoints for 1307 into ../logs/demo_single_node/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (10 secs).
# INFO:tensorflow:global_step/sec: 80.502
# INFO:tensorflow:loss = 0.269593, step = 1400 (1.242 sec)
# INFO:tensorflow:global_step/sec: 89.1277
# INFO:tensorflow:loss = 0.126714, step = 1500 (1.122 sec)
# INFO:tensorflow:global_step/sec: 89.8321
# INFO:tensorflow:loss = 0.240304, step = 1600 (1.113 sec)
# INFO:tensorflow:global_step/sec: 89.0618
# INFO:tensorflow:loss = 0.212661, step = 1700 (1.123 sec)
# INFO:tensorflow:global_step/sec: 90.3858
# INFO:tensorflow:loss = 0.184237, step = 1800 (1.107 sec)
# INFO:tensorflow:global_step/sec: 88.7395
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3798: ../logs/demo_single_node/model.ckpt-3798
# INFO:tensorflow:global_step/sec: 27.8263
# INFO:tensorflow:loss = 0.0356944, step = 3800 (3.594 sec)
# INFO:tensorflow:global_step/sec: 93.9325
# INFO:tensorflow:loss = 0.0127905, step = 3900 (1.065 sec)
# INFO:tensorflow:global_step/sec: 80.4808
# INFO:tensorflow:loss = 0.0378338, step = 4000 (1.245 sec)
# INFO:tensorflow:global_step/sec: 94.2212
# INFO:tensorflow:loss = 0.0460568, step = 4100 (1.058 sec)
# INFO:tensorflow:global_step/sec: 88.1891
# INFO:tensorflow:loss = 0.0797534, step = 4200 (1.135 sec)
# INFO:tensorflow:global_step/sec: 84.8645
# INFO:tensorflow:loss = 0.0759464, step = 4300 (1.178 sec)
# INFO:tensorflow:global_step/sec: 93.2157
# INFO:tensorflow:loss = 0.0945105, step = 4400 (1.072 sec)
# INFO:tensorflow:Saving checkpoints for 4463 into ../logs/demo_single_node/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# Number of model parameters 1072385
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-06-21:26:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../logs/demo_single_node/model.ckpt-4463
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-06-21:26:04
# INFO:tensorflow:Saving dict for global step 4463: acc = 0.987109, global_step = 4463, loss = 0.0341594
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4463: ../logs/demo_single_node/model.ckpt-4463
# INFO:tensorflow:global_step/sec: 26.2439
# INFO:tensorflow:loss = 0.0337306, step = 4500 (3.811 sec)
# INFO:tensorflow:global_step/sec: 88.6248
# INFO:tensorflow:loss = 0.0578213, step = 4600 (1.128 sec)
# INFO:tensorflow:global_step/sec: 89.1988
# INFO:tensorflow:loss = 0.0237757, step = 4700 (1.121 sec)
# INFO:tensorflow:global_step/sec: 86.179
# INFO:tensorflow:loss = 0.07085, step = 4800 (1.161 sec)
# INFO:tensorflow:global_step/sec: 91.8801
# INFO:tensorflow:loss = 0.0385529, step = 4900 (1.088 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ../logs/demo_single_node/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (10 secs).
# INFO:tensorflow:Calling model_fn.
# Number of model parameters 1072385
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-06-21:26:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../logs/demo_single_node/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-09-06-21:26:12
# INFO:tensorflow:Saving dict for global step 5000: acc = 0.989609, global_step = 5000, loss = 0.0298347
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: ../logs/demo_single_node/model.ckpt-5000
# INFO:tensorflow:Loss for final step: 0.0492432.
# ({'acc': 0.98960936, 'global_step': 5000, 'loss': 0.029834686}, [])

# %% [markdown]
# ### Examine learning curves

# %%
train_hist, valid_hist = get_training_history(model_dir=params.experiment_dir)
# Out:
# WARNING:tensorflow:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# WARNING:tensorflow:Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# INFO:tensorflow:No path found after ../logs/demo_single_node/events.out.tfevents.1536269098.maeve
# INFO:tensorflow:No path found after ../logs/demo_single_node/eval/events.out.tfevents.1536269114.maeve

# %%
plt.plot(valid_hist['loss']['steps'], valid_hist['loss']['values'], label='valid');
plt.plot(train_hist['loss']['steps'], train_hist['loss']['values'], label='train');
plt.ylabel('Loss');
plt.xlabel('Step');
plt.legend(loc=1);

# %%
plt.plot(valid_hist['acc']['steps'], valid_hist['acc']['values'], label='valid');
plt.ylabel('Acc');
plt.xlabel('Step');
plt.legend(loc=0);

# %%
plt.plot(train_hist['global_step/sec']['steps'], train_hist['global_step/sec']['values']);
plt.ylabel('global_step/sec');
plt.xlabel('Step');
